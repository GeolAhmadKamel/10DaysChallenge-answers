# %% [markdown]
# # Data Loading and Manipulation

# %% [markdown]
# ## Kindly load the las file of F02-1_logs.las well from the data folder
# ## Answer the following questions:
#
# >1. How many well logs in the file
# 2. How many data points (observations) in the welllogs.
# 3. Is there any null values? how much (%)/ well-log
# 4. Is there a relationship between DT and RHOB?

# %% [markdown]
# ### You can use the following liberaries for your assignment:
# > Numpy, Pandas, Matplotlib, seaborn, LASIO

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import lasio

# %%
# read/load las file # use slash / not backslash \
F02=lasio.read("C:/Users/AK/Desktop/GeoML-2.0 trials/10DaysChallenge/Dutch_F3_Logs/F02-1_logs.las")

# %%
# read the curves from inside the last file 
F02.keys()
# Out:
# ['DEPTH', 'RHOB', 'DT', 'GR', 'AI', 'AI_REL', 'PHIE']

# %%
# Shape
df=F02.df()
df.shape
# Out:
# (9680, 6)

# %%
# 1.How many well logs in the file
print ("No. of logs n the file = ",df.shape[1])
# Out:
# No. of logs n the file =  6

# %%
# 2.How many data points (observations) in the welllogs.
print ("No. of data points (observations) in the welllogs = ",df.shape[0])
# Out:
# No. of data points (observations) in the welllogs =  9680

# %%
# 3.Is there any null values?
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 9680 entries, 48.0 to 1499.8501
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RHOB    8253 non-null   float64
#  1   DT      9680 non-null   float64
#  2   GR      9666 non-null   float64
#  3   AI      9680 non-null   float64
#  4   AI_REL  9680 non-null   float64
#  5   PHIE    4906 non-null   float64
# dtypes: float64(6)
# memory usage: 529.4 KB
# RHOB      1427
# DT           0
# GR          14
# AI           0
# AI_REL       0
# PHIE      4774
# dtype: int64

# %%
# 3. how much (%)/ well-log
df.isna().sum()/ df.shape[0] *100
# Out:
# RHOB      14.741736
# DT         0.000000
# GR         0.144628
# AI         0.000000
# AI_REL     0.000000
# PHIE      49.318182
# dtype: float64

# %%
# 4.Is there a relationship between DT and RHOB? 
# ultivariate Scatter Plot using color and transperancy
plt.figure(figsize=(10,5))
plt.scatter(df.DT, df.RHOB) 
plt.colorbar()
plt.title('RHOB vs DT plot ')
plt.xlabel('DT')
plt.ylabel('RHOB')
plt.grid()
plt.show();
